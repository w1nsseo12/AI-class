# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats  # 과학용 계산 라이브러리
from sklearn.datasets import load_linnerud  # 사이킷런 데이타셋

# %%
linnerrud = load_linnerud()

# %%
linnerrud
# Out:
# {'data': array([[  5., 162.,  60.],
#         [  2., 110.,  60.],
#         [ 12., 101., 101.],
#         [ 12., 105.,  37.],
#         [ 13., 155.,  58.],
#         [  4., 101.,  42.],
#         [  8., 101.,  38.],
#         [  6., 125.,  40.],
#         [ 15., 200.,  40.],
#         [ 17., 251., 250.],
#         [ 17., 120.,  38.],
#         [ 13., 210., 115.],
#         [ 14., 215., 105.],
#         [  1.,  50.,  50.],
#         [  6.,  70.,  31.],
#         [ 12., 210., 120.],
#         [  4.,  60.,  25.],
#         [ 11., 230.,  80.],
#         [ 15., 225.,  73.],
#         [  2., 110.,  43.]]),
#  'feature_names': ['Chins', 'Situps', 'Jumps'],
#  'target': array([[191.,  36.,  50.],
#         [189.,  37.,  52.],
#         [193.,  38.,  58.],
#         [162.,  35.,  62.],
#         [189.,  35.,  46.],
#         [182.,  36.,  56.],
#         [211.,  38.,  56.],
#         [167.,  34.,  60.],
#         [176.,  31.,  74.],
#         [154.,  33.,  56.],
#         [169.,  34.,  50.],
# ...

# %%
df = pd.DataFrame(linnerrud.data, columns = linnerrud.feature_names)

df
# Out:
#     Chins  Situps  Jumps
# 0     5.0   162.0   60.0
# 1     2.0   110.0   60.0
# 2    12.0   101.0  101.0
# 3    12.0   105.0   37.0
# 4    13.0   155.0   58.0
# 5     4.0   101.0   42.0
# 6     8.0   101.0   38.0
# 7     6.0   125.0   40.0
# 8    15.0   200.0   40.0
# 9    17.0   251.0  250.0
# 10   17.0   120.0   38.0
# 11   13.0   210.0  115.0
# 12   14.0   215.0  105.0
# 13    1.0    50.0   50.0
# 14    6.0    70.0   31.0
# 15   12.0   210.0  120.0
# 16    4.0    60.0   25.0
# 17   11.0   230.0   80.0
# 18   15.0   225.0   73.0
# 19    2.0   110.0   43.0

# %%
df.shape
# Out:
# (20, 3)

# %%
df_target = pd.DataFrame(linnerrud.target, columns = linnerrud.target_names)

# %%
df_target
# Out:
#     Weight  Waist  Pulse
# 0    191.0   36.0   50.0
# 1    189.0   37.0   52.0
# 2    193.0   38.0   58.0
# 3    162.0   35.0   62.0
# 4    189.0   35.0   46.0
# 5    182.0   36.0   56.0
# 6    211.0   38.0   56.0
# 7    167.0   34.0   60.0
# 8    176.0   31.0   74.0
# 9    154.0   33.0   56.0
# 10   169.0   34.0   50.0
# 11   166.0   33.0   52.0
# 12   154.0   34.0   64.0
# 13   247.0   46.0   50.0
# 14   193.0   36.0   46.0
# 15   202.0   37.0   62.0
# 16   176.0   37.0   54.0
# 17   157.0   32.0   52.0
# 18   156.0   33.0   54.0
# 19   138.0   33.0   68.0

# %%
df = pd.concat([df, df_target], axis = 1)

df
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 0     5.0   162.0   60.0   191.0   36.0   50.0
# 1     2.0   110.0   60.0   189.0   37.0   52.0
# 2    12.0   101.0  101.0   193.0   38.0   58.0
# 3    12.0   105.0   37.0   162.0   35.0   62.0
# 4    13.0   155.0   58.0   189.0   35.0   46.0
# 5     4.0   101.0   42.0   182.0   36.0   56.0
# 6     8.0   101.0   38.0   211.0   38.0   56.0
# 7     6.0   125.0   40.0   167.0   34.0   60.0
# 8    15.0   200.0   40.0   176.0   31.0   74.0
# 9    17.0   251.0  250.0   154.0   33.0   56.0
# 10   17.0   120.0   38.0   169.0   34.0   50.0
# 11   13.0   210.0  115.0   166.0   33.0   52.0
# 12   14.0   215.0  105.0   154.0   34.0   64.0
# 13    1.0    50.0   50.0   247.0   46.0   50.0
# 14    6.0    70.0   31.0   193.0   36.0   46.0
# 15   12.0   210.0  120.0   202.0   37.0   62.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 17   11.0   230.0   80.0   157.0   32.0   52.0
# 18   15.0   225.0   73.0   156.0   33.0   54.0
# ...

# %%
df.drop(columns = ['Waist', 'Pulse'])
# Out:
#     Chins  Situps  Jumps  Weight
# 0     5.0   162.0   60.0   191.0
# 1     2.0   110.0   60.0   189.0
# 2    12.0   101.0  101.0   193.0
# 3    12.0   105.0   37.0   162.0
# 4    13.0   155.0   58.0   189.0
# 5     4.0   101.0   42.0   182.0
# 6     8.0   101.0   38.0   211.0
# 7     6.0   125.0   40.0   167.0
# 8    15.0   200.0   40.0   176.0
# 9    17.0   251.0  250.0   154.0
# 10   17.0   120.0   38.0   169.0
# 11   13.0   210.0  115.0   166.0
# 12   14.0   215.0  105.0   154.0
# 13    1.0    50.0   50.0   247.0
# 14    6.0    70.0   31.0   193.0
# 15   12.0   210.0  120.0   202.0
# 16    4.0    60.0   25.0   176.0
# 17   11.0   230.0   80.0   157.0
# 18   15.0   225.0   73.0   156.0
# 19    2.0   110.0   43.0   138.0

# %%
sns.pairplot(df, vars=['Chins', 'Situps', 'Jumps'], hue ='Weight')

plt.show()

# %%
# 2x4 subplot 이용. axs는 4x2
fig, axs = plt.subplots(figsize=(9,3), ncols=3, nrows=1)

lm_features = ['Chins', 'Situps', 'Jumps']

# i에는 인덱스가 feature에는 순차적으로 들어감
for i, feature in enumerate(lm_features):
    row = int (i/3)
    col = i%3

    # sns.regplot : 회귀직선을 그려줌
    sns.regplot(x=feature, y='Weight', data=df, ax=axs[row][col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10560\1160339632.py in <module>
#      10
#      11     # sns.regplot : 회귀직선을 그려줌
# ---> 12     sns.regplot(x=feature, y='Weight', data=df, ax=axs[row][col])
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_data=df.loc[:, ['Chins', 'Situps', 'Jumps']]
y_data=df.loc[:, 'Weight']
X_train, X_test, y_train, y_test=train_test_split(x_data,
                                                  y_data,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (16, 3) (16,)
# (4, 3) (4,)

# %%
X_train.head()
# Out:
#     Chins  Situps  Jumps
# 14    6.0    70.0   31.0
# 16    4.0    60.0   25.0
# 10   17.0   120.0   38.0
# 8    15.0   200.0   40.0
# 5     4.0   101.0   42.0

# %%
y_train.head()
# Out:
# 14    193.0
# 16    176.0
# 10    169.0
# 8     176.0
# 5     182.0
# Name: Weight, dtype: float64

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("회귀계수(기울기):", np.round(lr.coef_, 1)) #np: numpy, coef_: 피처에 대한 회귀 계수 값
print("상수항(절편):", np.round(lr.intercept_, 1))  #intercept_: 상수항(절편) 값
# Out:
# 회귀계수(기울기): [-1.  -0.1  0.2]
# 상수항(절편): 200.7

# %%
#예측값 저장
y_preds = lr.predict(X_test)

print(X_train.shape, X_test.shape)
# Out:
# (16, 3) (4, 3)

# %%
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)
print(f'MSE : {mse:.3f}, RMSE: {rmse:.3f}')
print(f'Variance score : {r2_score(y_test, y_preds):.3f}')
# Out:
# MSE : 1559.793, RMSE: 39.494
# Variance score : 0.115

# %%
print("절편 값:", lr.intercept_) # y축 절편값

# 회귀 계수(coefficient) : 독립변수의 변화에 따라 종속변수에 미치는 영향력이 크기
print("회귀계수:", np.round(lr.coef_,1))
# Out:
# 절편 값: 200.65050193110943
# 회귀계수: [-1.  -0.1  0.2]

# %%
#예측값 저장
y_test_pred=lr.predict(X_test)

plt.figure(figsize=(10,5))
plt.scatter(X_test['Chins'], y_test, label='y_test')
plt.scatter(X_test['Chins'], y_test_pred, c='r', label='y_pred')
#plt.plot(X_train, lr.predict(X_train), color='blue')
plt.show()
